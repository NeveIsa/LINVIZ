# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

from jupyterthemes import jtplot
jtplot.style(ticks=True, grid=True)

plt.rcParams['figure.figsize'] = [7, 7]



from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets


from functools import lru_cache

from uscmath225.transformations import *
from uscmath225.visualize import *
from uscmath225.interactive import *

import time

# %%
TFR = Transformer()
VIZ = Visualizer()
ICT = Interacter()
MCS = MatrixClassifier()

# %%
xcap = [1,0]
ycap = [0,1]
VIZ.vector(xcap,color="red")
VIZ.vector(ycap,color="green")

# %%
def viz_rotate(theta):
    rotM = TFR.rotation(theta)
    VIZ.matrix(rotM,plot_std_bases=True)
    VIZ.show()
    
    
ICT.angle(viz_rotate)
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='theta', layout=Layout(width='75…

# %%
def viz_reflecion(theta):
    refM = TFR.reflection(theta)
    VIZ.matrix(refM,plot_std_bases=True)
    VIZ.show()
    
ICT.angle(viz_reflecion)
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='theta', layout=Layout(width='75…

# %%
def viz_projection(theta):
    projM = TFR.projection(theta)
    VIZ.matrix(projM,plot_std_bases=True)
    VIZ.show()
    
ICT.angle(viz_projection)
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='theta', layout=Layout(width='75…

# %%
M = np.array([[4,2],[-4,2]])

# %%
P,D,PI = np.linalg.svd(M)

# %%
 VIZ.matrix(P @ PI)

# %%
D = np.diag(D)

# %%
print(MCS.analyze(P))
VIZ.matrix(V)
# Out:
# {'isSquare': True, 'isStretchOne': True, 'areAxesOrderPreserved': False, 'areAllColumnsUnitLength': True}

# %%
print(MCS.analyze(D))
VIZ.matrix(D)
S
# Out:
# {'isSquare': True, 'isStretchOne': False, 'areAxesOrderPreserved': True, 'areAllColumnsUnitLength': False}
# array([[8., 0.],
#        [0., 0.]])

# %%
VIZ.vector([1,1])

# %%
VIZ.vector(M @  [1,1])

# %%
VIZ.vector(PI @  [1,1])

# %%
VIZ.vector( D @ PI @  [1,1])

# %%
VIZ.vector( P @ D @ PI @  [1,1])
